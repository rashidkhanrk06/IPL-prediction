# %% [markdown]
# ## Import Necessary Libraries

# %%
import sys
import warnings
import numpy as np
import pandas as pd
import sklearn
from pathlib import Path
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
sys.path.append(str(Path.cwd().parent / 'src'))
import dataTransformer as fx

# %% [markdown]
# ## Display Setting

# %%
pd.set_option('display.max_columns',None)
sklearn.set_config(transform_output='pandas')
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Load Data

# %%
bolls = pd.read_csv(Path('../data/deliveries.csv'))
matches = pd.read_csv(Path('../data/matches.csv'))

# %%
matches.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %% [markdown]
# ## Basic Overview

# %%
print(f'matches shape: {matches.shape}')
print(matches.isnull().sum().loc[lambda x: x>0])
# Out:
# matches shape: (1095, 20)
# city                 51
# player_of_match       5
# winner                5
# result_margin        19
# target_runs           3
# target_overs          3
# method             1074
# dtype: int64

# %%
matches.team1.unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
matches.team2.unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Deccan Chargers',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Lucknow Super Giants',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
np.sort(matches.city.unique().tolist())
# Out:
# array(['Abu Dhabi', 'Ahmedabad', 'Bangalore', 'Bengaluru', 'Bloemfontein',
#        'Cape Town', 'Centurion', 'Chandigarh', 'Chennai', 'Cuttack',
#        'Delhi', 'Dharamsala', 'Dubai', 'Durban', 'East London',
#        'Guwahati', 'Hyderabad', 'Indore', 'Jaipur', 'Johannesburg',
#        'Kanpur', 'Kimberley', 'Kochi', 'Kolkata', 'Lucknow', 'Mohali',
#        'Mumbai', 'Nagpur', 'Navi Mumbai', 'Port Elizabeth', 'Pune',
#        'Raipur', 'Rajkot', 'Ranchi', 'Sharjah', 'Visakhapatnam', 'nan'],
#       dtype='<U32')

# %%
np.sort(matches.venue.unique()).shape
# Out:
# (58,)

# %%
bolls.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %% [markdown]
# ## Data Cleaning & Transformation

# %%
clean_matches = fx.clean_matches(matches)
clean_matches.head()
# Out:
#        id season        city        date match_type player_of_match  \
# 0  335982   2008   Bangalore  2008-04-18     League     BB McCullum
# 1  335983   2008  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984   2008       Delhi  2008-04-19     League     MF Maharoof
# 3  335985   2008      Mumbai  2008-04-20     League      MV Boucher
# 4  335986   2008     Kolkata  2008-04-20     League       DJ Hussey
#
#                                 venue                        team1  \
# 0               M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium              Kings XI Punjab
# 2                    Feroz Shah Kotla               Delhi Capitals
# 3                    Wankhede Stadium               Mumbai Indians
# 4                        Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4          Sunrisers Hyderabad          Sunrisers Hyderabad           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2               Delhi Capitals  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over    umpire1         umpire2 team1_short team2_short  \
# 0          20.0          N  Asad Rauf     RE Koertzen         RCB         KKR
# 1          20.0          N  MR Benson      SL Shastri        KXIP         CSK
# 2          20.0          N  Aleem Dar  GA Pratapkumar          DC          RR
# 3          20.0          N   SJ Davis       DJ Harper          MI         RCB
# 4          20.0          N  BF Bowden     K Hariharan         KKR          SH
#
#   winner_short toss_winner_short
# 0          KKR               RCB
# 1          CSK               CSK
# 2           DC                RR
# 3          RCB                MI
# 4          KKR                SH

# %%
clean_bolls =fx.deliveries_transform(fx.clean_deliveries(bolls))
clean_bolls.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN
#
#   team_batting team_bowling  score  wickets_left  current_sore  legal_ball  \
# 0          KKR          RCB    222            10             1           1
# 1          KKR          RCB    222            10             1           1
# 2          KKR          RCB    222            10             2           0
# 3          KKR          RCB    222            10             2           1
# 4          KKR          RCB    222            10             2           1
#
#    balls  ball_left  run_rate  chase_target  runs_left  req_rate
# 0      1        119  1.000000           222        221  1.857143
# 1      2        118  0.500000           222        221  1.872881
# 2      2        118  1.000000           222        220  1.864407
# 3      3        117  0.666667           222        220  1.880342
# 4      4        116  0.500000           222        220  1.896552

# %%
final_DF = fx.features_sectection(clean_bolls,clean_matches)
final_DF.head(2)
# Out:
#                   batting_team           bowling_team       city  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 1  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#    chase_target  current_sore  run_rate  ball_left  wickets_left  runs_left  \
# 0           222             1       1.0        119            10        221
# 1           222             2       2.0        119            10        220
#
#    result
# 0       0
# 1       0

# %%
current_teams = ['Kolkata Knight Riders', 
         'Chennai Super Kings',
         'Kings XI Punjab', 
         'Rajasthan Royals',
         'Mumbai Indians',
         'Delhi Capitals',
         'Royal Challengers Bangalore',
         'Sunrisers Hyderabad',
         'Lucknow Super Giants',
         'Gujarat Titans'
         ]
len(current_teams)
# Out:
# 10

# %%
final_DF = final_DF.loc[lambda x: x.batting_team.isin(current_teams) & x.bowling_team.isin(current_teams) ]

# %%
final_DF.dropna(inplace=True)

# %%
final_DF = final_DF.sample(final_DF.shape[0])

# %%
final_DF.shape
# Out:
# (115732, 10)

# %%
final_DF.head()
# Out:
#                batting_team                 bowling_team       city  \
# 101397       Delhi Capitals               Gujarat Titans       Pune
# 29292        Delhi Capitals          Chennai Super Kings      Delhi
# 35483        Mumbai Indians        Kolkata Knight Riders     Mumbai
# 78129   Sunrisers Hyderabad  Royal Challengers Bangalore  Bangalore
# 92853        Delhi Capitals               Mumbai Indians      Dubai
#
#         chase_target  current_sore  run_rate  ball_left  wickets_left  \
# 101397           171           144  1.358491         14             1
# 29292            110            12  2.400000        115            10
# 35483            140            77  0.916667         36             7
# 78129            218           106  1.452055         47             8
# 92853            200            66  1.081967         59             5
#
#         runs_left  result
# 101397         27       0
# 29292          98       1
# 35483          63       0
# 78129         112       0
# 92853         134       0

# %% [markdown]
# ## Data Preparation

# %%
X = final_DF.drop('result', axis=1)
y = final_DF['result']

# %%
X_train, X_test, y_train, y_test = train_test_split(X
                                                    ,y
                                                    ,test_size=0.33
                                                    ,random_state=42)

# %%
trf = ColumnTransformer([
                        ('trf',OneHotEncoder(sparse_output=False,drop='first')
                              ,['batting_team','bowling_team','city'])
], remainder='passthrough')

# %% [markdown]
# ## Model Traning

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

pipe = Pipeline([
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracy_score(y_test,y_pred)
# Out:
# 0.9977744030163385

# %%
import pickle
pickle.dump(pipe,open('.\model\model.pkl','wb'))
